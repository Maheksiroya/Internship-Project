# %%
import os
import tensorflow as tf
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout,Conv2D,MaxPooling2D
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.optimizers import Adam

from keras.layers import GlobalAveragePooling2D

# %%
data_dir = 'mango_5/' #Add full path to dataset
filepaths = []
labels = []

dir_names = os.listdir(data_dir)
print(dir_names)

for dir in dir_names:
    dir_path = os.path.join(data_dir, dir)
    filelist = os.listdir(dir_path)
    for file in filelist:
        fpath = os.path.join(dir_path, file)
        filepaths.append(fpath)
        labels.append(dir)

# Concatenate data paths with labels into one dataframe
file_name_series = pd.Series(filepaths, name= 'filepaths')
labels_series = pd.Series(labels, name='labels')
df = pd.concat([file_name_series, labels_series], axis= 1)
# Out:
# ['Cutting Weevil', 'Die Back', 'Gall Midge', 'Healthy', 'Powdery Mildew', 'Sooty Mould', 'Unhealthy']

# %%
# df.to_csv('mango.csv')
# df = pd.read_csv('mango.csv')
df.shape
# Out:
# (4000, 2)

# %%
train_df, dummy_df = train_test_split(df,  train_size= 0.8, shuffle= True, random_state= 123)
valid_df, test_df = train_test_split(dummy_df,  train_size= 0.5, shuffle= True, random_state= 123)
train_df.shape, valid_df.shape,test_df.shape
# Out:
# ((3200, 2), (400, 2), (400, 2))

# %%
# Set the image dimensions and batch size
img_width, img_height = 224, 224
batch_size = 16

# Define the data generators for the train and test sets
tr_gen = ImageDataGenerator(
    rescale=1./255,         # Scale the pixel values from 0-255 to 0-1
    rotation_range=40,      # Randomly rotate the images up to 40 degrees
    width_shift_range=0.2,  # Randomly shift the images horizontally up to 20% of the width
    height_shift_range=0.2, # Randomly shift the images vertically up to 20% of the height
    shear_range=0.2,       # Randomly apply shear transformations
    zoom_range=0.2,         # Randomly zoom in on the images
    horizontal_flip=True,   # Randomly flip the images horizontally
    fill_mode='nearest')    # Fill any empty pixels with the nearest available pixel


ts_gen = ImageDataGenerator(rescale=1./255)

# %%
train_gen = tr_gen.flow_from_dataframe(train_df,
                                       x_col= 'filepaths',
                                       y_col= 'labels',
                                       target_size= (img_width, img_height),
                                       class_mode= 'categorical',
                                       color_mode= 'rgb',
                                       shuffle= True,
                                       batch_size= batch_size)

valid_gen = ts_gen.flow_from_dataframe(valid_df,
                                      x_col= 'filepaths',
                                      y_col= 'labels',
                                      target_size= (img_width, img_height),
                                      class_mode= 'categorical',
                                      color_mode= 'rgb',
                                      shuffle= True,
                                      batch_size= batch_size)

test_gen = ts_gen.flow_from_dataframe(test_df,
                                      x_col= 'filepaths',
                                      y_col= 'labels',
                                      target_size= (img_width, img_height),
                                      class_mode= 'categorical',
                                      color_mode= 'rgb',
                                      shuffle= True,
                                      batch_size= batch_size)
# Out:
# Found 3200 validated image filenames belonging to 7 classes.
# Found 400 validated image filenames belonging to 7 classes.
# Found 400 validated image filenames belonging to 7 classes.

# %%
device_name = tf.test.gpu_device_name()
if len(device_name) > 0:
    print("Found GPU at: {}".format(device_name))
else:
    device_name = "/device:CPU:0"
    print("No GPU, using {}.".format(device_name))
# Out:
# No GPU, using /device:CPU:0.

# %%
with tf.device(device_name):

    base_model = InceptionV3(
      weights='imagenet',
      include_top=False,
      input_shape=(img_width, img_height, 3))
    for layer in base_model.layers:
      layer.trainable = False

    model = Sequential()
    model.add(base_model)
    model.add(GlobalAveragePooling2D())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(7, activation='sigmoid'))        # Create a TensorFlow model.

    opt = Adam(learning_rate=0.0001)

    model.compile(
    optimizer=opt,
    loss= "binary_crossentropy",
    metrics=['accuracy'])
    # Compile the model on the GPU.
    # Once the model has been created and compiled on the GPU, it can be
    # trained as per usual.

from keras.callbacks import EarlyStopping
early_stop = EarlyStopping(patience=10, verbose=1)

# %%
# %%time
history = model.fit(
    train_gen,
    epochs=50,
    validation_data=test_gen,
    callbacks=[early_stop],
    verbose=1)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 929s 4s/step - loss: 0.3470 - accuracy: 0.4909 - val_loss: 0.1807 - val_accuracy: 0.8525
# Epoch 2/50
# 200/200 [==============================] - 917s 5s/step - loss: 0.2100 - accuracy: 0.7544 - val_loss: 0.1206 - val_accuracy: 0.8800
# Epoch 3/50
# 200/200 [==============================] - 749s 4s/step - loss: 0.1643 - accuracy: 0.8281 - val_loss: 0.0977 - val_accuracy: 0.9000
# Epoch 4/50
# 200/200 [==============================] - 608s 3s/step - loss: 0.1399 - accuracy: 0.8603 - val_loss: 0.0827 - val_accuracy: 0.9250
# Epoch 5/50
# 200/200 [==============================] - 606s 3s/step - loss: 0.1200 - accuracy: 0.8838 - val_loss: 0.0733 - val_accuracy: 0.9300
# Epoch 6/50
# 200/200 [==============================] - 608s 3s/step - loss: 0.1072 - accuracy: 0.8981 - val_loss: 0.0639 - val_accuracy: 0.9400
# Epoch 7/50
# 200/200 [==============================] - 515s 3s/step - loss: 0.0953 - accuracy: 0.9141 - val_loss: 0.0580 - val_accuracy: 0.9425
# Epoch 8/50
# 200/200 [==============================] - 468s 2s/step - loss: 0.0898 - accuracy: 0.9162 - val_loss: 0.0542 - val_accuracy: 0.9475
# Epoch 9/50
# 200/200 [==============================] - 474s 2s/step - loss: 0.0761 - accuracy: 0.9381 - val_loss: 0.0489 - val_accuracy: 0.9600
# Epoch 10/50
# 200/200 [==============================] - 472s 2s/step - loss: 0.0771 - accuracy: 0.9247 - val_loss: 0.0460 - val_accuracy: 0.9575
# Epoch 11/50
# 200/200 [==============================] - 394s 2s/step - loss: 0.0689 - accuracy: 0.9406 - val_loss: 0.0442 - val_accuracy: 0.9575
# Epoch 12/50
# 200/200 [==============================] - 379s 2s/step - loss: 0.0690 - accuracy: 0.9394 - val_loss: 0.0401 - val_accuracy: 0.9600
# Epoch 13/50
# 200/200 [==============================] - 373s 2s/step - loss: 0.0627 - accuracy: 0.9478 - val_loss: 0.0370 - val_accuracy: 0.9600
# Epoch 14/50
# 200/200 [==============================] - 381s 2s/step - loss: 0.0550 - accuracy: 0.9519 - val_loss: 0.0353 - val_accuracy: 0.9700
# Epoch 15/50
# 200/200 [==============================] - 379s 2s/step - loss: 0.0527 - accuracy: 0.9588 - val_loss: 0.0349 - val_accuracy: 0.9650
# Epoch 16/50
# 200/200 [==============================] - 380s 2s/step - loss: 0.0541 - accuracy: 0.9544 - val_loss: 0.0342 - val_accuracy: 0.9575
# Epoch 17/50
# 200/200 [==============================] - 384s 2s/step - loss: 0.0517 - accuracy: 0.9553 - val_loss: 0.0319 - val_accuracy: 0.9675
# Epoch 18/50
# 200/200 [==============================] - 379s 2s/step - loss: 0.0493 - accuracy: 0.9575 - val_loss: 0.0315 - val_accuracy: 0.9675
# Epoch 19/50
# 200/200 [==============================] - 379s 2s/step - loss: 0.0472 - accuracy: 0.9600 - val_loss: 0.0295 - val_accuracy: 0.9650
# Epoch 20/50
# 200/200 [==============================] - 380s 2s/step - loss: 0.0463 - accuracy: 0.9591 - val_loss: 0.0281 - val_accuracy: 0.9700
# Epoch 21/50
# 200/200 [==============================] - 384s 2s/step - loss: 0.0430 - accuracy: 0.9631 - val_loss: 0.0284 - val_accuracy: 0.9750
# Epoch 22/50
# 200/200 [==============================] - 377s 2s/step - loss: 0.0382 - accuracy: 0.9709 - val_loss: 0.0260 - val_accuracy: 0.9750
# Epoch 23/50
# 200/200 [==============================] - 378s 2s/step - loss: 0.0386 - accuracy: 0.9681 - val_loss: 0.0251 - val_accuracy: 0.9700
# Epoch 24/50
# 200/200 [==============================] - 386s 2s/step - loss: 0.0417 - accuracy: 0.9597 - val_loss: 0.0248 - val_accuracy: 0.9775
# Epoch 25/50
# 200/200 [==============================] - 376s 2s/step - loss: 0.0375 - accuracy: 0.9653 - val_loss: 0.0243 - val_accuracy: 0.9775
# Epoch 26/50
# 200/200 [==============================] - 380s 2s/step - loss: 0.0372 - accuracy: 0.9647 - val_loss: 0.0230 - val_accuracy: 0.9800
# Epoch 27/50
# 200/200 [==============================] - 377s 2s/step - loss: 0.0357 - accuracy: 0.9669 - val_loss: 0.0240 - val_accuracy: 0.9725
# Epoch 28/50
# 200/200 [==============================] - 379s 2s/step - loss: 0.0363 - accuracy: 0.9681 - val_loss: 0.0218 - val_accuracy: 0.9800
# Epoch 29/50
# 200/200 [==============================] - 379s 2s/step - loss: 0.0316 - accuracy: 0.9703 - val_loss: 0.0218 - val_accuracy: 0.9800
# Epoch 30/50
# 200/200 [==============================] - 380s 2s/step - loss: 0.0322 - accuracy: 0.9722 - val_loss: 0.0218 - val_accuracy: 0.9800
# Epoch 31/50
# 200/200 [==============================] - 381s 2s/step - loss: 0.0325 - accuracy: 0.9741 - val_loss: 0.0199 - val_accuracy: 0.9850
# Epoch 32/50
# 200/200 [==============================] - 380s 2s/step - loss: 0.0307 - accuracy: 0.9737 - val_loss: 0.0212 - val_accuracy: 0.9775
# Epoch 33/50
# 200/200 [==============================] - 382s 2s/step - loss: 0.0302 - accuracy: 0.9750 - val_loss: 0.0199 - val_accuracy: 0.9775
# Epoch 34/50
# 200/200 [==============================] - 376s 2s/step - loss: 0.0297 - accuracy: 0.9734 - val_loss: 0.0186 - val_accuracy: 0.9850
# Epoch 35/50
# 200/200 [==============================] - 381s 2s/step - loss: 0.0277 - accuracy: 0.9775 - val_loss: 0.0213 - val_accuracy: 0.9800
# Epoch 36/50
# 200/200 [==============================] - 377s 2s/step - loss: 0.0287 - accuracy: 0.9744 - val_loss: 0.0215 - val_accuracy: 0.9775
# Epoch 37/50
# 200/200 [==============================] - 424s 2s/step - loss: 0.0271 - accuracy: 0.9766 - val_loss: 0.0190 - val_accuracy: 0.9825
# Epoch 38/50
# 200/200 [==============================] - 707s 4s/step - loss: 0.0277 - accuracy: 0.9759 - val_loss: 0.0157 - val_accuracy: 0.9850
# Epoch 39/50
# 200/200 [==============================] - 670s 3s/step - loss: 0.0249 - accuracy: 0.9781 - val_loss: 0.0163 - val_accuracy: 0.9875
# Epoch 40/50
# 200/200 [==============================] - 455s 2s/step - loss: 0.0242 - accuracy: 0.9809 - val_loss: 0.0165 - val_accuracy: 0.9875
# Epoch 41/50
# 200/200 [==============================] - 466s 2s/step - loss: 0.0250 - accuracy: 0.9778 - val_loss: 0.0164 - val_accuracy: 0.9875
# Epoch 42/50
# 200/200 [==============================] - 467s 2s/step - loss: 0.0238 - accuracy: 0.9775 - val_loss: 0.0161 - val_accuracy: 0.9875
# Epoch 43/50
# 200/200 [==============================] - 475s 2s/step - loss: 0.0239 - accuracy: 0.9797 - val_loss: 0.0162 - val_accuracy: 0.9875
# Epoch 44/50
# 200/200 [==============================] - 475s 2s/step - loss: 0.0251 - accuracy: 0.9772 - val_loss: 0.0178 - val_accuracy: 0.9825
# Epoch 45/50
# 200/200 [==============================] - 471s 2s/step - loss: 0.0230 - accuracy: 0.9806 - val_loss: 0.0169 - val_accuracy: 0.9825
# Epoch 46/50
# 200/200 [==============================] - 475s 2s/step - loss: 0.0233 - accuracy: 0.9797 - val_loss: 0.0154 - val_accuracy: 0.9875
# Epoch 47/50
# 200/200 [==============================] - 472s 2s/step - loss: 0.0215 - accuracy: 0.9822 - val_loss: 0.0161 - val_accuracy: 0.9875
# Epoch 48/50
# 200/200 [==============================] - 470s 2s/step - loss: 0.0242 - accuracy: 0.9769 - val_loss: 0.0157 - val_accuracy: 0.9875
# Epoch 49/50
# 200/200 [==============================] - 469s 2s/step - loss: 0.0222 - accuracy: 0.9812 - val_loss: 0.0161 - val_accuracy: 0.9850
# Epoch 50/50
# 200/200 [==============================] - 463s 2s/step - loss: 0.0207 - accuracy: 0.9822 - val_loss: 0.0144 - val_accuracy: 0.9875
# Wall time: 6h 26min 32s

# %%
loss, accuracy = model.evaluate(train_gen)
print('Train accuracy:', accuracy)
loss, accuracy = model.evaluate(valid_gen)
print("Valid accuracy:", accuracy)
loss, accuracy = model.evaluate(test_gen)
print('Test accuracy:', accuracy)
# Out:
# 200/200 [==============================] - 443s 2s/step - loss: 0.0142 - accuracy: 0.9875
# Train accuracy: 0.987500011920929
# 25/25 [==============================] - 24s 946ms/step - loss: 0.0187 - accuracy: 0.9750
# Valid accuracy: 0.9750000238418579
# 25/25 [==============================] - 27s 1s/step - loss: 0.0144 - accuracy: 0.9875
# Test accuracy: 0.987500011920929

# %%
# %%time
import matplotlib.pyplot as plt

tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (50, 20))
#plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest,  c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
#plt.subplot_tool()
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.4,
                    hspace=0.4)
#plt.tight_layout(pad=20.0)
plt.show()
# Out:
# Wall time: 10.2 s
